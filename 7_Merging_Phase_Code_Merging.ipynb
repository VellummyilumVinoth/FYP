# %%
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Load JSON data
json_file_path = '/content/leetcode-solutions.jsonl'
data = pd.read_json(json_file_path, lines=True)

# Convert to CSV
csv_file_path = '/content/drive/MyDrive/Final FYP/leetcode_kaggle.csv'
data.to_csv(csv_file_path, index=False)

# %%
data_size = data.shape
data_size
# Out:
# (2360, 6)

# %%
data.head()
# Out:
#    id                                            slug  \
# 0   1                                         two-sum
# 1   2                                 add-two-numbers
# 2   3  longest-substring-without-repeating-characters
# 3   4                     median-of-two-sorted-arrays
# 4   5                   longest-palindromic-substring
#
#                                             title difficulty  \
# 0                                         Two Sum       Easy
# 1                                 Add Two Numbers     Medium
# 2  Longest Substring Without Repeating Characters     Medium
# 3                     Median of Two Sorted Arrays       Hard
# 4                   Longest Palindromic Substring     Medium
#
#                                              content  \
# 0  Given an array of integers `nums` and an integ...
# 1  You are given two **non-empty** linked lists r...
# 2  Given a string `s`, find the length of the **l...
# ...

# %%
# !pip install openai==0.28
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import openai

# Set up your OpenAI API key
openai.api_key = ""

# Define a function to ask a question and get a response from GPT-3.5 Turbo
def ask_gpt(subproblem):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert Java programmer. Provide a Java code snippet for each subproblem."},
            {"role": "user", "content": f"Java code snippet for the following subproblem:\n{subproblem}"}
        ]
    )
    return response.choices[0].message['content']

# Example prompt divided into subproblems
subproblems = [
    "1. Initialize a dummy ListNode with a value of 0.",
    "2. Set current to that dummy ListNode, and set carry to 0.",
    "3. Iterate over the list nodes of l1 and l2, as well as the carry, in a while loop until all are null or 0.",
    "4. Calculate the sum of the node values and carry, store the carry for the next iteration, and store the value % 10 in a new ListNode connected to the current ListNode.",
    "5. Shift the current ListNode, l1, and l2 to the next node if available.",
    "6. Return the next of the dummy ListNode as a result."
]

# Get the response from GPT-3.5 Turbo for each subproblem
responses = [ask_gpt(subproblem) for subproblem in subproblems]

# Print the responses
for i, response in enumerate(responses, 1):
    print(f"Subproblem {i}:\n{response}\n")

# Optionally, combine the snippets into a single function for completeness
print("Complete function:")

for response in responses:
    print(response)
# Out:
# Subproblem 1:
# ```java
# ListNode dummy = new ListNode(0);
# ```
#
# Subproblem 2:
# ```java
# ListNode current = dummy;
# int carry = 0;
# ```
#
# Subproblem 3:
# ```java
# ListNode dummy = new ListNode(0);
# ListNode current = dummy;
# int carry = 0;
#
# while (l1 != null || l2 != null || carry != 0) {
#     int sum = (l1 != null ? l1.val : 0) + (l2 != null ? l2.val : 0) + carry;
#     carry = sum / 10;
#     current.next = new ListNode(sum % 10);
#     current = current.next;
#
#     if (l1 != null) l1 = l1.next;
#     if (l2 != null) l2 = l2.next;
# }
#
# return dummy.next;
# ```
#
# Subproblem 4:
# ```java
# public class ListNode {
#     int val;
#     ListNode next;
#
#     public ListNode(int val) {
#         this.val = val;
#     }
# }
#
# public ListNode addTwoNumbers(ListNode l1, ListNode l2) {
#     ListNode dummyHead = new ListNode(0);
#     ListNode p = l1, q = l2, curr = dummyHead;
#     int carry = 0;
#
#     while (p != null || q != null) {
# ...

# %%
import openai

# Set up your OpenAI API key
openai.api_key = ""

# Define a function to ask a question and get a response from GPT-3.5 Turbo
def ask_gpt(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are an expert Java programmer. Give the compilable Java cohesive function only as output. Not to return any comments.\n"},
            {"role": "user", "content": f"Please merge the following Java code snippets into a single, compilable cohesive function:\n\n{prompt}"}
        ]
    )
    return response.choices[0].message['content']

# Combine the subproblem snippets into a single prompt
subproblems = [
    """
    public class ListNode {
        int val;
        ListNode next;

        public ListNode(int val) {
            this.val = val;
        }
    }

    ListNode dummy = new ListNode(0);
    """,
    """
    ListNode current = dummy;
    int carry = 0;
    """,
    """
    ListNode dummy = new ListNode(0);
    ListNode current = dummy;

    while (l1 != null || l2 != null || carry != 0) {
        int sum = (l1 != null ? l1.val : 0) + (l2 != null ? l2.val : 0) + carry;
        carry = sum / 10;
        current.next = new ListNode(sum % 10);

        current = current.next;
        l1 = l1 != null ? l1.next : null;
        l2 = l2 != null ? l2.next : null;
    }

    ListNode result = dummy.next;
    return result;
    """,
    """
    public class ListNode {
        int val;
        ListNode next;

        public ListNode(int val) {
            this.val = val;
        }
    }

    public ListNode addTwoNumbers(ListNode l1, ListNode l2) {
        ListNode dummyHead = new ListNode(0);
        ListNode current = dummyHead;
        int carry = 0;

        ListNode p = l1;
        ListNode q = l2;

        while (p != null || q != null) {
            int x = (p != null) ? p.val : 0;
            int y = (q != null) ? q.val : 0;

            int sum = x + y + carry;
            carry = sum / 10;

            current.next = new ListNode(sum % 10);
            current = current.next;

            if (p != null) p = p.next;
            if (q != null) q = q.next;
        }

        if (carry > 0) {
            current.next = new ListNode(carry);
        }

        return dummyHead.next;
    }
    """,
    """
    if (l1 != null) {
        l1 = l1.next;
    }
    if (l2 != null) {
        l2 = l2.next;
    }
    """,
    """
    public ListNode getNextOfDummy(ListNode dummy) {
        return dummy.next;
    }
    """
]

# Combine the snippets into a single prompt
combined_prompt = "\n".join(subproblems)

# Get the response from GPT-3.5 Turbo
response = ask_gpt(combined_prompt)

# Print the response
print(response)
# Out:
# Here is the merged Java function incorporating the provided code snippets into a single cohesive function:
#
# ```java
# public class ListNode {
#     int val;
#     ListNode next;
#
#     public ListNode(int val) {
#         this.val = val;
#     }
# }
#
# public ListNode addTwoNumbers(ListNode l1, ListNode l2) {
#     ListNode dummy = new ListNode(0);
#     ListNode current = dummy;
#     int carry = 0;
#
#     while (l1 != null || l2 != null || carry != 0) {
#         int sum = (l1 != null ? l1.val : 0) + (l2 != null ? l2.val : 0) + carry;
#         carry = sum / 10;
#         current.next = new ListNode(sum % 10);
#
#         current = current.next;
#         if (l1 != null) {
#             l1 = l1.next;
#         }
#         if (l2 != null) {
#             l2 = l2.next;
#         }
#     }
#
#     if (carry > 0) {
#         current.next = new ListNode(carry);
#     }
#
#     return dummy.next;
# }
#
# public ListNode getNextOfDummy(ListNode dummy) {
#     return dummy.next;
# }
# ...
